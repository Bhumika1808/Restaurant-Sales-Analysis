# %% [markdown]
# ###  Task:  Task: Restaurant Ratings

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("Dataset  (1).csv")
df
# Out:
#       Restaurant ID           Restaurant Name  Country Code              City  \
# 0           6317637          Le Petit Souffle           162       Makati City
# 1           6304287          Izakaya Kikufuji           162       Makati City
# 2           6300002    Heat - Edsa Shangri-La           162  Mandaluyong City
# 3           6318506                      Ooma           162  Mandaluyong City
# 4           6314302               Sambo Kojin           162  Mandaluyong City
# ...             ...                       ...           ...               ...
# 9546        5915730               Naml۱ Gurme           208         ��stanbul
# 9547        5908749              Ceviz A��ac۱           208         ��stanbul
# 9548        5915807                     Huqqa           208         ��stanbul
# 9549        5916112               A���k Kahve           208         ��stanbul
# 9550        5927402  Walter's Coffee Roastery           208         ��stanbul
#
# ...

# %% [markdown]
# ###  Analyze the distribution of aggregate ratings and determine the most common rating range.

# %%
comm_rating=df['Aggregate rating'].value_counts()

# %%
print("the  most common rating range is :")
comm_rating.head(1)
# Out:
# the  most common rating range is :
# Aggregate rating
# 0.0    2148
# Name: count, dtype: int64

# %%
plt.figure(figsize=(8, 5))
sns.histplot(df['Aggregate rating'], bins=30, color='purple')
plt.xlabel("Aggregate Rating")
plt.ylabel("Number of Restaurants")
plt.title("Distribution of Aggregate Ratings")
plt.show()

# %% [markdown]
# ### Calculate the average number of votes received by restaurants.

# %%
avg_vote= df['Votes'].mean()

# %%
avg_vote
# Out:
# 156.909747670401

# %%
print("The average number of votes received by restaurants is ")
avg_vote
# Out:
# The average number of votes received by restaurants is
# 156.909747670401
