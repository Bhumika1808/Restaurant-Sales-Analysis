# %% [markdown]
# #### Task: Price Range Distribution

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("Dataset  (1).csv")
df
# Out:
#       Restaurant ID           Restaurant Name  Country Code              City  \
# 0           6317637          Le Petit Souffle           162       Makati City
# 1           6304287          Izakaya Kikufuji           162       Makati City
# 2           6300002    Heat - Edsa Shangri-La           162  Mandaluyong City
# 3           6318506                      Ooma           162  Mandaluyong City
# 4           6314302               Sambo Kojin           162  Mandaluyong City
# ...             ...                       ...           ...               ...
# 9546        5915730               Naml۱ Gurme           208         ��stanbul
# 9547        5908749              Ceviz A��ac۱           208         ��stanbul
# 9548        5915807                     Huqqa           208         ��stanbul
# 9549        5916112               A���k Kahve           208         ��stanbul
# 9550        5927402  Walter's Coffee Roastery           208         ��stanbul
#
# ...

# %% [markdown]
#  ### Create a histogram or bar chart to visualize the distribution of price ranges among the restaurants.

# %%
plt.hist(x=df['Price range'],)
plt.title("Distribution of price among restaurants")
plt.xlabel("price range")
plt.ylabel("no.of restaurants")
plt.xticks([1,2,3,4])
plt.show()

# %% [markdown]
#  ### Calculate the percentage of restaurants in each price range category.

# %%
df['Price range'].unique()
# Out:
# array([3, 4, 2, 1], dtype=int64)

# %%
count_res=df.groupby(by='Price range')['Restaurant Name'].count()
count_res
# Out:
# Price range
# 1    4444
# 2    3113
# 3    1408
# 4     586
# Name: Restaurant Name, dtype: int64

# %%
total_res=len(df)

# %%
for cuisines in count_res:
    percent=(count_res/total_res)*100

# %%
print("The percentage of restaurants in each price range category:")
percent
# Out:
# The percentage of restaurants in each price range category:
# Price range
# 1    46.529159
# 2    32.593446
# 3    14.741912
# 4     6.135483
# Name: Restaurant Name, dtype: float64
