# %% [markdown]
# ###  Task: Cuisine Combination

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("Dataset  (1).csv")
df
# Out:
#       Restaurant ID           Restaurant Name  Country Code              City  \
# 0           6317637          Le Petit Souffle           162       Makati City
# 1           6304287          Izakaya Kikufuji           162       Makati City
# 2           6300002    Heat - Edsa Shangri-La           162  Mandaluyong City
# 3           6318506                      Ooma           162  Mandaluyong City
# 4           6314302               Sambo Kojin           162  Mandaluyong City
# ...             ...                       ...           ...               ...
# 9546        5915730               Naml۱ Gurme           208         ��stanbul
# 9547        5908749              Ceviz A��ac۱           208         ��stanbul
# 9548        5915807                     Huqqa           208         ��stanbul
# 9549        5916112               A���k Kahve           208         ��stanbul
# 9550        5927402  Walter's Coffee Roastery           208         ��stanbul
#
# ...

# %% [markdown]
# ### Identify the most common combinations of cuisines in the dataset.

# %%
cuisine_combo = df['Cuisines'].value_counts()
cuisine_avg_ratings = df.groupby('Cuisines')['Aggregate rating'].mean().sort_values(ascending=False)

# %%
print("The most common combinations of cuisines in the dataset are as follows: ")
cuisine_avg_ratings.head(5)
# Out:
# The most common combinations of cuisines in the dataset are as follows:
# Cuisines
# Italian, Deli              4.9
# Hawaiian, Seafood          4.9
# American, Sandwich, Tea    4.9
# Continental, Indian        4.9
# European, Asian, Indian    4.9
# Name: Aggregate rating, dtype: float64

# %% [markdown]
# ### determine if certain cuisine combinations tend to have higher ratings

# %%
max_rating= cuisine_avg_ratings.iloc[0]
print("The max rating is:" ,max_rating)
# Out:
# The max rating is: 4.9
